# %% [markdown]
# # Prompting with Gemini
# Notebook for experimenting different promting techniques with Gemini

# %% [markdown]
# Install the required dependencies with the following command.

# %%
# %pip install google-generativeai

# %% [markdown]
# Import the required libraries.

# %%
import google.generativeai as genai
import os
# from google.colab import userdata # uncomment and use in colab

# %% [markdown]
# Insert your Gemini API key to the following command and import the Gemini model.

# %%
API_KEY="AIzaSyDD4ej5oWTRyoqOAS3eAK2Bk_Ei7-dZ1aQ" # Add you API key here
# API_KEY = userdata.get('AIzaSyDD4ej5oWTRyoqOAS3eAK2Bk_Ei7-dZ1aQ') # uncomment and use this in Google Colab
genai.configure(api_key=API_KEY)

model = genai.GenerativeModel('gemini-2.5-flash')

# %% [markdown]
# Modify the `system_prompt` to experiment with different prompting approaches.

# %%
system_prompt = "Hello! You are smart expert of French culinary. Analyze the French dessert Tarte Tatin"

# %% [markdown]
# We create a list of messages so that we keep history in the context. If you want to clear the messages later in this notebook, add the line `messages = []` to a new line cell in the notebook.

# %%
messages = []
messages.append(system_prompt)

# %% [markdown]
# Get the response from Gemini model by providing the prompt in a messages list to it.

# %%
r = model.generate_content(messages).text

# %% [markdown]
# Print the output of the model.

# %%
print(r)
# Out:
# Ah, Tarte Tatin! A true marvel, a testament to both genius and delightful happenstance, holding a most cherished place in the pantheon of French desserts. As a connoisseur of French culinary arts, I regard it not merely as a tart, but as a culinary philosophy in itself.
#
# Let us dissect this masterpiece:
#
# **I. The Legend and Origins: A Story of Fortuitous Flaws**
#
# The tale of Tarte Tatin is as delightful and sticky as its caramel. It hails from the late 19th century, specifically the Hotel Tatin in Lamotte-Beuvron, Sologne, run by the sisters Caroline and Stéphanie Tatin. While the exact "accident" varies in telling – Stéphanie, either overworked, distracted, or simply clumsy, supposedly either:
# 1.  **Over-caramelized the apples** and, in a panic, topped them with pastry and baked the whole thing.
# 2.  **Forgot the pastry entirely**, baked the apples, and then quickly slapped a piece of pastry on top to finish it.
# ...

# %% [markdown]
# Let's define a new prompt.

# %%
user_input = "Create a Markdown table listing strengths and weaknesses of the French dessert Tarte Tatin."

# %% [markdown]
# Let's add athe new prompt to the messages list.

# %%
messages.append(user_input)

# %% [markdown]
# Again we generate the output with the Gemini model.

# %%
r = model.generate_content(messages).text

# %% [markdown]
# ... and print the output.

# %%
print(r)
# Out:
# Bonjour! As your dedicated French culinary expert, I'm delighted to delve into the captivating world of Tarte Tatin. This seemingly simple, yet profoundly delicious, upside-down apple tart is a true testament to French rustic elegance and the magic that happens when humble ingredients are treated with respect and a touch of culinary alchemy. Its origin story, a delightful accident by the Tatin sisters in the late 19th century, only adds to its charm.
#
# Let's dissect this iconic dessert, exploring its strengths that have cemented its place in gastronomy, and its weaknesses that present challenges to even seasoned chefs.
#
# Here is a Markdown table outlining the strengths and weaknesses of Tarte Tatin:
#
# ---
#
# ## Tarte Tatin: Strengths & Weaknesses Analysis
#
# | Strengths                                    | Weaknesses                                     |
# | :------------------------------------------- | :--------------------------------------------- |
# ...
